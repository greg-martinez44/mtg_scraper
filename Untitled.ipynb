# %%
import numpy as np
import os
import pandas as pd
import requests
import sqlite3
import re

from bs4 import BeautifulSoup

# %% [markdown]
# # Get Event Links
#
# * Establish connection to sqlite database file
# * Get event links from db file
# * Store in a dataframe

# %%
os.getcwd()
# Out:
# '/Users/gregmartinez/projects/mtg_scraper'

# %%
db = "dbs/links.db"
conn = sqlite3.connect(db)

event_df = pd.read_sql("SELECT * FROM event", conn)

conn.close()

# %%
# Cleaning
event_df["date"] = pd.to_datetime(event_df["date"], format="%d/%m/%y")

# %%
event_df.sort_values(by="date", ascending=False)
# Out:
#       id                                               name  \
# 361  362                     Free Daily @ Owl Central Games
# 360  361  Japan Championship 2020 Winter Daily Trial @ B...
# 320  321                 Monday Night Magic @ Plague League
# 321  322                        Weekly @ The Mythic Society
# 322  323  Japan Championship 2020 Winter Daily Trial @ B...
# ..   ...                                                ...
# 228  229                             Free FNM @ Equalssport
# 229  230                    Dealers at Home! @ MagicDealers
# 230  231                                FNM @ Lotus eSports
# 231  232      SCG Tour Online - Challenge @ Star City Games
# 232  233                             Free Open @ UGCardshop
#
#                                            link       date
# 361  https://www.mtgtop8.com/event?e=28287&f=ST 2020-11-25
# 360  https://www.mtgtop8.com/event?e=28286&f=ST 2020-11-25
# 320  https://www.mtgtop8.com/event?e=28265&f=ST 2020-11-24
# 321  https://www.mtgtop8.com/event?e=28266&f=ST 2020-11-24
# 322  https://www.mtgtop8.com/event?e=28269&f=ST 2020-11-24
# ..                                          ...        ...
# 228  https://www.mtgtop8.com/event?e=27190&f=ST 2020-09-04
# 229  https://www.mtgtop8.com/event?e=27193&f=ST 2020-09-04
# 230  https://www.mtgtop8.com/event?e=27194&f=ST 2020-09-04
# 231  https://www.mtgtop8.com/event?e=27172&f=ST 2020-09-03
# 232  https://www.mtgtop8.com/event?e=27187&f=ST 2020-09-03
#
# [362 rows x 4 columns]

# %%
events = list(event_df.sort_values("date", ascending=False)["link"])
events
# Out:
# ['https://www.mtgtop8.com/event?e=28287&f=ST',
#  'https://www.mtgtop8.com/event?e=28286&f=ST',
#  'https://www.mtgtop8.com/event?e=28265&f=ST',
#  'https://www.mtgtop8.com/event?e=28266&f=ST',
#  'https://www.mtgtop8.com/event?e=28269&f=ST',
#  'https://www.mtgtop8.com/event?e=28273&f=ST',
#  'https://www.mtgtop8.com/event?e=28274&f=ST',
#  'https://www.mtgtop8.com/event?e=28277&f=ST',
#  'https://www.mtgtop8.com/event?e=28267&f=ST',
#  'https://www.mtgtop8.com/event?e=28268&f=ST',
#  'https://www.mtgtop8.com/event?e=28262&f=ST',
#  'https://www.mtgtop8.com/event?e=28245&f=ST',
#  'https://www.mtgtop8.com/event?e=28250&f=ST',
#  'https://www.mtgtop8.com/event?e=28263&f=ST',
#  'https://www.mtgtop8.com/event?e=28275&f=ST',
#  'https://www.mtgtop8.com/event?e=28219&f=ST',
#  'https://www.mtgtop8.com/event?e=28220&f=ST',
#  'https://www.mtgtop8.com/event?e=28232&f=ST',
#  'https://www.mtgtop8.com/event?e=28238&f=ST',
#  'https://www.mtgtop8.com/event?e=27329&f=ST',
#  'https://www.mtgtop8.com/event?e=27367&f=ST',
#  'https://www.mtgtop8.com/event?e=27423&f=ST',
#  'https://www.mtgtop8.com/event?e=27343&f=ST',
#  'https://www.mtgtop8.com/event?e=27307&f=ST',
#  'https://www.mtgtop8.com/event?e=27305&f=ST',
#  'https://www.mtgtop8.com/event?e=27303&f=ST',
#  'https://www.mtgtop8.com/event?e=27302&f=ST',
#  'https://www.mtgtop8.com/event?e=27295&f=ST',
#  'https://www.mtgtop8.com/event?e=27245&f=ST',
#  'https://www.mtgtop8.com/event?e=27238&f=ST',
#  'https://www.mtgtop8.com/event?e=27240&f=ST',
#  'https://www.mtgtop8.com/event?e=27220&f=ST',
#  'https://www.mtgtop8.com/event?e=27221&f=ST',
#  'https://www.mtgtop8.com/event?e=27222&f=ST',
#  'https://www.mtgtop8.com/event?e=27258&f=ST',
#  'https://www.mtgtop8.com/event?e=27308&f=ST',
#  'https://www.mtgtop8.com/event?e=27231&f=ST',
#  'https://www.mtgtop8.com/event?e=27239&f=ST',
#  'https://www.mtgtop8.com/event?e=27225&f=ST',
#  'https://www.mtgtop8.com/event?e=27223&f=ST',
#  'https://www.mtgtop8.com/event?e=27224&f=ST',
#  'https://www.mtgtop8.com/event?e=27229&f=ST',
#  'https://www.mtgtop8.com/event?e=27246&f=ST',
#  'https://www.mtgtop8.com/event?e=27190&f=ST',
#  'https://www.mtgtop8.com/event?e=27193&f=ST',
#  'https://www.mtgtop8.com/event?e=27194&f=ST',
#  'https://www.mtgtop8.com/event?e=27172&f=ST',
#  'https://www.mtgtop8.com/event?e=27187&f=ST']

# %% [markdown]
# ### Event with Two Players

# %%
html = requests.get(events[0])
soup = BeautifulSoup(html.text)

body = soup.body

# %%
deck1 = body.find_all("div", class_="W14")
deck1_rank = deck1[0].text
deck1_name = deck1[1].find("a").text

print(deck1_rank, ", ", deck1_name)

deck2 = body.find_all("div", class_="S14")
deck2_rank = deck2[0].text
deck2_name = deck2[1].find("a").text

print(deck2_rank, ", ", deck2_name)
print(len(deck2))
# Out:
# 1 ,  Gruul Aggro
# 2 ,  UW Control
# 5

# %%
players = body.find_all("div", class_="G11")
player1 = players[0].find("a").text
player2 = players[1].find("a").text

print(player1, player2, sep="\n")
# Out:
# Antimo Morlando
# Umberto Veneruso

# %% [markdown]
# ### Event with One Player

# %%
html = requests.get(events[1])
soup = BeautifulSoup(html.text)
body = soup.body

# %%
deck = body.find_all("div", class_="W14")
deck_rank = deck[0].text
deck_name = deck[1].find("a").text
print(deck_rank, ", ", deck_name)

nothing = body.find_all("div", class_="S14")
print(len(nothing))
# Out:
# 1 ,  Red Deck Wins
# 3

# %%
player = body.find_all("div", class_="G11")
print(len(player))
player1 = player[0].find("a").text
player1
# Out:
# 1
# 'Ricardo Azeredo'

# %% [markdown]
# ### Event with Multiple Players

# %%
html = requests.get(events[5])
soup = BeautifulSoup(html.text)
body = soup.body

# %%
html.url
# Out:
# 'https://www.mtgtop8.com/event?e=27921&f=ST'

# %%
deck1 = body.find_all("div", class_="W14")
deck1_rank = deck1[0].text
deck1_name = deck1[1].find("a").text
print(deck1_rank, ", ", deck1_name)

other_decks = body.find_all("div", class_="S14")
ranks = []
deck_names = []
for idx, result in enumerate(other_decks[:-3]):
    if idx % 2 == 0:
        ranks.append(result.text)
    else:
        deck_names.append(result.find("a").text)
print(ranks)
print(deck_names)
# Out:
# 1 ,  Gruul Aggro
# ['2', '3-4', '3-4', '5-8', '5-8', '5-8', '5-8']
# ['Selesnya Aggro', 'Dimir Rogue', 'Gruul Aggro', 'Dimir Flash', 'Gruul Aggro', 'Gruul Aggro', 'Rakdos Aggro']

# %%
players = body.find_all("div", class_="G11")

for player in players:
    print(player.find("a").text)
# Out:
# Junichi Takayama
# Yoshiro Mikami
# Kazuki Katou
# Norikazu Ichikawa
# Yasuhiro Shinkai
# Drmonday
# ?? ????
# Teruya Kakumae

# %% [markdown]
# ### Looping through all events for deck name & players
#
# * Winner is W14
# * Others are S14; if rank is reported in points, then it uses S12

# %%
for event in events[:10]:
    html = requests.get(event)
    soup = BeautifulSoup(html.text)
    body = soup.body
    
    print(html.url)
    try:
        deck1 = body.find_all("div", class_="W14")
        deck1_rank = deck1[0].text
        deck1_name = deck1[1].find("a").text
        deck1_link = deck1[1].find("a").get("href")
    except IndexError:
        deck1_rank = 1
        deck1_name = deck1[0].find("a").text
        deck1_link = deck1[0].find("a").get("href")
        print(deck1_rank, ", ", deck1_name, ", ", deck1_link)
        print("The above was a problem url!")
    print(deck1_rank, ", ", deck1_name, ", ", deck1_link)
# Out:
# https://www.mtgtop8.com/event?e=28287&f=ST
# 1 ,  Dimir Control ,  ?e=28287&d=423952&f=ST
# https://www.mtgtop8.com/event?e=28286&f=ST
# 1 ,  Naya Aggro ,  ?e=28286&d=423944&f=ST
# https://www.mtgtop8.com/event?e=28265&f=ST
# 1 ,  Mono Green Aggro ,  ?e=28265&d=423809&f=ST
# https://www.mtgtop8.com/event?e=28266&f=ST
# 1 ,  Dimir Control ,  ?e=28266&d=423812&f=ST
# https://www.mtgtop8.com/event?e=28269&f=ST
# 1 ,  Temur Ultimatum ,  ?e=28269&d=423828&f=ST
# https://www.mtgtop8.com/event?e=28273&f=ST
# 1 ,  Dimir Control ,  ?e=28273&d=423864&f=ST
# https://www.mtgtop8.com/event?e=28274&f=ST
# 1 ,  Grixis Control ,  ?e=28274&d=423868&f=ST
# https://www.mtgtop8.com/event?e=28277&f=ST
# 1 ,  Dimir Control ,  ?e=28277&d=423881&f=ST
# https://www.mtgtop8.com/event?e=28267&f=ST
# 1 ,  Gruul Aggro ,  ?e=28267&d=423820&f=ST
# https://www.mtgtop8.com/event?e=28268&f=ST
# 1 ,  Temur Ultimatum ,  ?e=28268&d=423824&f=ST

# %%
from src.sqldb import SQLDatabase

def get_deck_table():
    """Opens event table and gets deck data from each link in event table"""
    event_df = _open_sql("event")
    results = []
    for link, event in zip(event_df["link"], event_df["name"]):
        html = requests.get(link)
        soup = BeautifulSoup(html.text, features="lxml")
        body = soup.body

        names, ranks, links = _get_winners(body)

        has_points = False
        if _is_points(ranks[0]):
            has_points = True

        other_names, other_ranks, other_links = _add_other_decks(body, has_points)
        names.extend(other_names)
        ranks.extend(other_ranks)
        links.extend(other_links)

        players = _get_players(body, names)
        

        assert _are_equal_length(names, ranks, players, links), \
            "names: " + str(len(names)) \
            + ", ranks: " + str(len(ranks)) \
            + ", players: " + str(len(players)) \
            + ", links: " + str(len(links)) \
            + " at " + html.url
        assert _are_equal_length(
            list(zip(names, ranks, players, links)), names, ranks, players, links)

        results.extend(
            [
                (event, player, name, rank, link)
                for (player, name, rank, link)
                in zip(players, names, ranks, links)
            ]
        )

    return results

def _open_sql(table):
    with SQLDatabase() as sql_db:
        return sql_db.get_dataframe_from(table)

def _get_winners(body):
    try:
        winner_rank = body.find_all("div", class_="W12")[1].text
        winner_name = body.find_all("div", class_="W14")[0].find("a").text
        winner_link = body.find_all("div", class_="W14")[0].find("a").get("href")
    except (IndexError, AttributeError):
        winner_rank = body.find_all("div", class_="W14")[0].text
        winner_name = body.find_all("div", class_="W14")[1].find("a").text
        winner_link = body.find_all("div", class_="W14")[1].find("a").get("href")
    finally:
        return [winner_name], [winner_rank], [winner_link]


def _add_other_decks(body, has_points=False):
    names = []
    ranks = []
    links = []
    if has_points:
        for name in body.find_all("div", class_="S14")[:-3]:
            assert not _is_malformed(
                name.text), "Bad name - " + name.text
            names.append(name.text.strip())
            links.append(name.find("a").get("href"))
        for points in body.find_all("div", class_="S12"):
            if not _should_be_skipped(points.text):
                assert _is_points(points.text), "Malformed Points " + \
                    points.text
                ranks.append(points.text.strip())
    else:
        for idx, result in enumerate(body.find_all("div", class_="S14")[:-3]):
            if idx % 2 == 0:
                if not _is_rank(result.text):
                    break
                ranks.append(result.text.strip())
            else:
                assert not _is_malformed(
                    result.text), "Bad name - " + result.text
                names.append(result.text.strip())
                links.append(result.find("a").get("href"))
    return names, ranks, links


def _get_players(body, names):
    result = []
    for player in body.find_all("div", class_="G11")[:len(names)]:
        result.append(player.find("a").text)
    return result


def _is_malformed(name):
    return re.match("^\$[0-9]*\ \(.*\)$", name) or re.match("^[0-9]*\ TIX$", name)


def _should_be_skipped(rank):
    return rank == "close" or rank == "Companion card"


def _is_points(rank):
    return re.match("^[0-9]*\ pts$", rank)


def _is_rank(rank):
    return re.match("^[0-9]*-[0-9]*$", rank) or re.match("^[0-9]*$", rank)


def _are_equal_length(*args):
    equal = True
    length1 = len(args[0])
    for arg in args:
        if len(arg) != length1:
            equal = False
    return equal

# %%
result = get_deck_table()

# %%
result
# Out:
# [('FNM @ MTG Arena Campania',
#   'Antimo Morlando',
#   'Gruul Aggro',
#   '1',
#   '?e=27938&d=421597&f=ST'),
#  ('FNM @ MTG Arena Campania',
#   'Umberto Veneruso',
#   'UW Control',
#   '2',
#   '?e=27938&d=421598&f=ST'),
#  ('Torneios @ Ludo Quest',
#   'Ricardo Azeredo',
#   'Red Deck Wins',
#   '1',
#   '?e=27939&d=421599&f=ST'),
#  ("All Hallow's Eve FNM @ Gamer's Gauntlet",
#   'Boris Pan',
#   'Rakdos Aggro',
#   '1',
#   '?e=27940&d=421600&f=ST'),
#  ('Japan Championship 2020 Autumn Last Chance Trial @ BIG Magic',
#   'Kazuyuki Takimura',
#   'Gruul Aggro',
#   '1',
#   '?e=27925&d=421512&f=ST'),
#  ('Japan Championship 2020 Autumn Last Chance Trial @ BIG Magic',
#   'Tomohiro Tsuda',
#   'Gruul Aggro',
#   '2',
#   '?e=27925&d=421513&f=ST'),
#  ('Japan Championship 2020 Autumn Last Chance Trial @ BIG Magic',
#   'Takahiro Omiya',
#   'Gruul Aggro',
#   '3-4',
#   '?e=27925&d=421515&f=ST'),
#  ('Japan Championship 2020 Autumn Last Chance Trial @ BIG Magic',
#   'Tomohiro Mashima',
#   'Rakdos Aggro',
#   '3-4',
#   '?e=27925&d=421514&f=ST'),
#  ('Japan Championship 2020 Autumn Last Chance Trial @ BIG Magic',
#   'Hideki Yakushi',
#   'Boros Cycling Aggro',
#   '5-8',
#   '?e=27925&d=421517&f=ST'),
#  ('Japan Championship 2020 Autumn Last Chance Trial @ BIG Magic',
#   'Drmonday',
#   'Gruul Aggro',
#   '5-8',
#   '?e=27925&d=421518&f=ST'),
#  ('Japan Championship 2020 Autumn Last Chance Trial @ BIG Magic',
#   'Calm',
#   'Gruul Aggro',
#   '5-8',
#   '?e=27925&d=421519&f=ST'),
#  ('Japan Championship 2020 Autumn Last Chance Trial @ BIG Magic',
#   'Tomonori Hirami',
#   'Rakdos Control',
#   '5-8',
#   '?e=27925&d=421516&f=ST'),
#  ('Free Daily @ Owl Central Games',
#   'Rashid Davis',
#   'Rakdos Control',
#   '1',
#   '?e=27918&d=421478&f=ST'),
#  ('Free Daily @ Owl Central Games',
#   'Daniel Alamos',
#   'Gruul Aggro',
#   '2',
#   '?e=27918&d=421479&f=ST'),
#  ('Free Daily @ Owl Central Games',
#   'Hilário Nunes',
#   'Gruul Aggro',
#   '3-4',
#   '?e=27918&d=421480&f=ST'),
#  ('Free Daily @ Owl Central Games',
#   'Abel Jacoby',
#   'Mono Black Aggro',
#   '3-4',
#   '?e=27918&d=421481&f=ST'),
#  ('Japan Championship 2020 Autumn Last Chance Trial @ BIG Magic',
#   'Junichi Takayama',
#   'Gruul Aggro',
#   '1',
#   '?e=27921&d=421484&f=ST'),
#  ('Japan Championship 2020 Autumn Last Chance Trial @ BIG Magic',
#   'Yoshiro Mikami',
#   'Selesnya Aggro',
#   '2',
#   '?e=27921&d=421485&f=ST'),
#  ('Japan Championship 2020 Autumn Last Chance Trial @ BIG Magic',
#   'Kazuki Katou',
#   'Dimir Rogue',
#   '3-4',
#   '?e=27921&d=421486&f=ST'),
#  ('Japan Championship 2020 Autumn Last Chance Trial @ BIG Magic',
#   'Norikazu Ichikawa',
#   'Gruul Aggro',
#   '3-4',
#   '?e=27921&d=421487&f=ST'),
#  ('Japan Championship 2020 Autumn Last Chance Trial @ BIG Magic',
#   'Yasuhiro Shinkai',
#   'Dimir Flash',
#   '5-8',
#   '?e=27921&d=421490&f=ST'),
#  ('Japan Championship 2020 Autumn Last Chance Trial @ BIG Magic',
#   'Drmonday',
#   'Gruul Aggro',
#   '5-8',
#   '?e=27921&d=421489&f=ST'),
#  ('Japan Championship 2020 Autumn Last Chance Trial @ BIG Magic',
#   '?? ????',
#   'Gruul Aggro',
#   '5-8',
#   '?e=27921&d=421491&f=ST'),
#  ('Japan Championship 2020 Autumn Last Chance Trial @ BIG Magic',
#   'Teruya Kakumae',
#   'Rakdos Aggro',
#   '5-8',
#   '?e=27921&d=421488&f=ST'),
#  ('Monday Night Magic @ Plague League',
#   'Matthew Davis',
#   'UW Control',
#   '1',
#   '?e=27886&d=421193&f=ST'),
#  ('Monday Night Magic @ Plague League',
#   'Bogdan Simonov',
#   'Rakdos Aggro',
#   '2',
#   '?e=27886&d=421194&f=ST'),
#  ('Event @ Lotus eSports',
#   'Howtoplay',
#   'Rakdos Control',
#   '1',
#   '?e=27898&d=421353&f=ST'),
#  ('Event @ Lotus eSports',
#   'Mikail Nogueira',
#   'Rakdos Aggro',
#   '2',
#   '?e=27898&d=421354&f=ST'),
#  ('Event @ Lotus eSports',
#   'Masatoshi Ota',
#   'Abzan DOOM Yorion',
#   '3-4',
#   '?e=27898&d=421356&f=ST'),
#  ('Event @ Lotus eSports',
#   'Santiago Ramirez',
#   'Gruul Aggro',
#   '3-4',
#   '?e=27898&d=421355&f=ST'),
#  ('Japan Championship 2020 Autumn - Last Chance Trial @ BIG Magic',
#   'Uragram',
#   'Dimir Mill',
#   '1',
#   '?e=27901&d=421373&f=ST'),
#  ('Japan Championship 2020 Autumn - Last Chance Trial @ BIG Magic',
#   'Ken Sawada',
#   'Gruul Aggro',
#   '2',
#   '?e=27901&d=421374&f=ST'),
#  ('Japan Championship 2020 Autumn - Last Chance Trial @ BIG Magic',
#   'Shinnosuke Wanaka',
#   'Gruul Aggro',
#   '3-4',
#   '?e=27901&d=421376&f=ST'),
#  ('Japan Championship 2020 Autumn - Last Chance Trial @ BIG Magic',
#   'Keita Tonouchi',
#   'Rakdos Control',
#   '3-4',
#   '?e=27901&d=421375&f=ST'),
#  ('Japan Championship 2020 Autumn - Last Chance Trial @ BIG Magic',
#   'Shunichi Nakajima',
#   'Gruul Aggro',
#   '5-8',
#   '?e=27901&d=421378&f=ST'),
#  ('Japan Championship 2020 Autumn - Last Chance Trial @ BIG Magic',
#   'Norikazu Ichikawa',
#   'Gruul Aggro',
#   '5-8',
#   '?e=27901&d=421379&f=ST'),
#  ('Japan Championship 2020 Autumn - Last Chance Trial @ BIG Magic',
#   'Kota Nakanishi',
#   'Gruul Aggro',
#   '5-8',
#   '?e=27901&d=421380&f=ST'),
#  ('Japan Championship 2020 Autumn - Last Chance Trial @ BIG Magic',
#   'Yoshiki Yamashita',
#   'UW Control',
#   '5-8',
#   '?e=27901&d=421377&f=ST'),
#  ('Gentry ! @ The Gentry Magic League',
#   'Teddie Andersson',
#   'Izzet Control',
#   '1',
#   '?e=27902&d=421381&f=ST'),
#  ('Gentry ! @ The Gentry Magic League',
#   'Karl Dewhirst-lister',
#   'Sultai Mutate Aggro',
#   '2',
#   '?e=27902&d=421382&f=ST'),
#  ('Gentry ! @ The Gentry Magic League',
#   'Jelle Lauwers',
#   'Izzet Control Kick',
#   '3-4',
#   '?e=27902&d=421383&f=ST'),
#  ('Gentry ! @ The Gentry Magic League',
#   'Lars Meeussen',
#   'Mono Black Aggro',
#   '3-4',
#   '?e=27902&d=421384&f=ST')]

# %%
player_table =[]
for item in result:
    player_table.append(item[1].split(maxsplit=1))

# %%
player_table
# Out:
# [['Antimo', 'Morlando'],
#  ['Umberto', 'Veneruso'],
#  ['Ricardo', 'Azeredo'],
#  ['Boris', 'Pan'],
#  ['Kazuyuki', 'Takimura'],
#  ['Tomohiro', 'Tsuda'],
#  ['Takahiro', 'Omiya'],
#  ['Tomohiro', 'Mashima'],
#  ['Hideki', 'Yakushi'],
#  ['Drmonday'],
#  ['Calm'],
#  ['Tomonori', 'Hirami'],
#  ['Rashid', 'Davis'],
#  ['Daniel', 'Alamos'],
#  ['Hilário', 'Nunes'],
#  ['Abel', 'Jacoby'],
#  ['Junichi', 'Takayama'],
#  ['Yoshiro', 'Mikami'],
#  ['Kazuki', 'Katou'],
#  ['Norikazu', 'Ichikawa'],
#  ['Yasuhiro', 'Shinkai'],
#  ['Drmonday'],
#  ['??', '????'],
#  ['Teruya', 'Kakumae'],
#  ['Matthew', 'Davis'],
#  ['Bogdan', 'Simonov'],
#  ['Howtoplay'],
#  ['Mikail', 'Nogueira'],
#  ['Masatoshi', 'Ota'],
#  ['Santiago', 'Ramirez'],
#  ['Uragram'],
#  ['Ken', 'Sawada'],
#  ['Shinnosuke', 'Wanaka'],
#  ['Keita', 'Tonouchi'],
#  ['Shunichi', 'Nakajima'],
#  ['Norikazu', 'Ichikawa'],
#  ['Kota', 'Nakanishi'],
#  ['Yoshiki', 'Yamashita'],
#  ['Teddie', 'Andersson'],
#  ['Karl', 'Dewhirst-lister'],
#  ['Jelle', 'Lauwers'],
#  ['Lars', 'Meeussen']]

# %%
for item in result:
    print(item)
# Out:
# ('FNM @ MTG Arena Campania', 'Antimo Morlando', 'Gruul Aggro', '1', '?e=27938&d=421597&f=ST')
# ('FNM @ MTG Arena Campania', 'Umberto Veneruso', 'UW Control', '2', '?e=27938&d=421598&f=ST')
# ('Torneios @ Ludo Quest', 'Ricardo Azeredo', 'Red Deck Wins', '1', '?e=27939&d=421599&f=ST')
# ("All Hallow's Eve FNM @ Gamer's Gauntlet", 'Boris Pan', 'Rakdos Aggro', '1', '?e=27940&d=421600&f=ST')
# ('Japan Championship 2020 Autumn Last Chance Trial @ BIG Magic', '
f=ST')
# ('Japan Championship 2020 Autumn - Last Chance Trial @ BIG Magic', 'Shinnosuke Wanaka', 'Gruul Aggro', '3-4', '?e=27901&d=421376&f=ST')
# ('Japan Championship 2020 Autumn - Last Chance Trial @ BIG Magic', 'Keita Tonouchi', 'Rakdos Control', '3-4', '?e=27901&d=421375&f=ST')
# ('Japan Championship 2020 Autumn - Last Chance Trial @ BIG Magic', 'Shunichi Nakajima', 'Gruul Aggro', '5-8', '?e=27901&d=421378&f=ST')
# ('Japan Championship 2020 Autumn - Last Chance Trial @ BIG Magic', 'Norikazu Ichikawa', 'Gruul Aggro', '5-8', '?e=27901&d=421379&f=ST')
# ('Japan Championship 2020 Autumn - Last Chance Trial @ BIG Magic', 'Kota Nakanishi', 'Gruul Aggro', '5-8', '?e=27901&d=421380&f=ST')
# ('Japan Championship 2020 Autumn - Last Chance Trial @ BIG Magic', 'Yoshiki Yamashita', 'UW Control', '5-8', '?e=27901&d=421377&f=ST')
# ('Gentry ! @ The Gentry Magic League', 'Teddie Andersson', 'Izzet Control', '1', '?e=27902&d=421381&f=ST')
# ('Gentry ! @ The Gentry Magic League', 'Karl Dewhirst-lister', 'Sultai Mutate Aggro', '2', '?e=27902&d=421382&f=ST')
# ('Gentry ! @ The Gentry Magic League', 'Jelle Lauwers', 'Izzet Control Kick', '3-4', '?e=27902&d=421383&f=ST')
# ('Gentry ! @ The Gentry Magic League', 'Lars Meeussen', 'Mono Black Aggro', '3-4', '?e=27902&d=421384&f=ST')

# %% [markdown]
# ## Getting List of Cards

# %%
latest_event = events[0]
latest_event
# Out:
# 'https://www.mtgtop8.com/event?e=28287&f=ST'

# %%
html = requests.get(latest_event)
soup = BeautifulSoup(html.text)
body = soup.body

for item in body.find_all("td", class_="G14"):
    result = item.text.strip().split(maxsplit=1)
    print(html.url)
    print(result + [item.find_all("div")[0].get("id")[:2]])
# Out:
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['1', 'Castle Locthwain', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['2', 'Clearwater Pathway', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['4', 'Dismal Backwater', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['8', 'Island', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['8', 'Swamp', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['3', 'Temple of Deceit', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['2', 'Brazen Borrower', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['1', 'Lochmere Serpent', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['3', 'Murderous Rider', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['2', 'Voracious Greatshark', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['2', "Bloodchief's Thirst", 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['1', 'Cling to Dust', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['2', 'Eliminate', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['3', 'Essence Scatter', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['2', 'Extinction Event', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['4', 'Heartless Act', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['2', 'Negate', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['1', 'Rewind', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['2', "Ashiok's Erasure", 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['2', 'Ashiok, Nightmare Muse', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['1', 'Kiora Bests the Sea God', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['3', 'Shark Typhoon', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['1', 'Ugin, the Spirit Dragon', 'md']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['2', 'Agonizing Remorse', 'sb']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['2', "Bloodchief's Thirst", 'sb']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['2', 'Demonic Embrace', 'sb']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['2', 'Eat to Extinction', 'sb']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['2', "Elspeth's Nightmare", 'sb']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['1', 'Feed the Swarm', 'sb']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['2', "Pharika's Libation", 'sb']
# https://www.mtgtop8.com/event?e=28287&f=ST
# ['2', 'Rankle, Master of Pranks', 'sb']

# %%
conn = ""
# Out:
# Help on class SQLDatabase in module src.sqldb:
#
# class SQLDatabase(builtins.object)
#  |  SQLDatabase(db_name=None)
#  |
#  |  API for interacting with SQL database.
#  |
#  |  Methods defined here:
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, *args)
#  |
#  |  __init__(self, db_name=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  add_new(self, item, table)
#  |
#  |  close(self)
#  |
#  |  get_dataframe_from(self, table)
#  |
#  |  union_events(self, data, table)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
db = "dbs/links.db"
conn = sqlite3.connect(db)

# %%
cursor = conn.cursor()

# %%
cursor.execute("SELECT id FROM EVENT WHERE name = 'Free FNM @ Equalssport'").fetchall()
# Out:
# [(153,), (211,), (229,)]
